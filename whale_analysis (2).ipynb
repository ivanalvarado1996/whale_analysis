# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csv_path = Path("Resources/whale_returns.csv")

# %%
whale_df = pd.read_csv(csv_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csv_path = Path("Resources/algo_returns.csv")

# %%
algo_df = pd.read_csv(csv_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csv_path = Path("Resources/sp500_history.csv")
sp500_df = pd.read_csv

# %%
sp500_df = pd.read_csv(csv_path, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['Close'] = sp500_df['Close'].str.replace("$","")
sp500_df['Close'] = sp500_df['Close'].astype('float')
print(sp500_df)
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06
# ...             ...
# 2012-10-05  1460.93
# 2012-10-04  1461.40
# 2012-10-03  1450.99
# 2012-10-02  1445.75
# 2012-10-01  1444.49
#
# [1649 rows x 1 columns]
# C:\Users\sagui\anaconda3\envs\alpacaenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_df.pct_change()
sp500_daily_returns
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1649 rows x 1 columns]

# %%
# Drop nulls
sp500_daily_returns.dropna(inplace=True)
sp500_daily_returns
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.
columns = ["S&P 500 Returns"]
sp500_daily_returns.columns = columns
sp500_daily_returns.head()
# Out:
#             S&P 500 Returns
# Date
# 2019-04-22        -0.008764
# 2019-04-18        -0.001011
# 2019-04-17        -0.001577
# 2019-04-16         0.002279
# 2019-04-15        -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
column_appended_data = pd.concat([whale_df, algo_df, sp500_daily_returns], axis="columns", join="inner")
column_appended_data
column_appended_data.sort_index(inplace=True)
column_appended_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P 500 Returns
# Date
# 2015-03-03 -0.000949         0.004408
# 2015-03-04  0.002416        -0.001195
# 2015-03-05  0.004323         0.014378
# 2015-03-06 -0.011460        -0.003929
# 2015-03-09  0.001303         0.017254

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
column_appended_data.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns = (1 + column_appended_data).cumprod() - 1
cumulative_returns.head()
# Plot cumulative returns
cumulative_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %%
column_appended_data.plot.box(figsize = (15, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
whale_volatility = whale_df.std() * np.sqrt(252)
whale_volatility.sort_values(inplace=True)
whale_volatility.plot.box(title='Whale Risk')
# Out:
# <AxesSubplot:title={'center':'Whale Risk'}>

# %%
algo_volatility = algo_df.std() * np.sqrt(252)
algo_volatility.sort_values(inplace=True)
algo_volatility.plot.box(title='Algo Risk')
# Out:
# <AxesSubplot:title={'center':'Algo Risk'}>

# %%
sp500_volatility = sp500_daily_returns.std() * np.sqrt(252)
sp500_volatility.sort_values(inplace=True)
sp500_volatility.plot.box(title='S&P 500 Risk')
# Out:
# <AxesSubplot:title={'center':'S&P 500 Risk'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_portfolio_std = column_appended_data.std()
all_portfolio_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500 Returns                0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std = sp500_daily_returns.std()

# Determine which portfolios are riskier than the S&P 500
sp500_std[0] < all_portfolio_std
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                          True
# S&P 500 Returns                 True
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
all_portfolio_std * np.sqrt(252)
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500 Returns                0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_portfolio_std = column_appended_data.rolling(window=21).std()
# Plot the rolling standard deviation
all_portfolio_std
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# 2015-03-09                        NaN                 NaN
# ...                               ...                 ...
# 2019-04-15                   0.006804            0.006225
# 2019-04-16                   0.006711            0.006224
# 2019-04-17                   0.006773            0.006370
# 2019-04-18                   0.006633            0.006303
# 2019-04-22                   0.005915            0.006400
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                          NaN                     NaN       NaN
# 2015-03-05                          NaN                     NaN       NaN
# 2015-03-06                          NaN                     NaN       NaN
# 2015-03-09                          NaN                     NaN       NaN
# ...                                 ...                     ...       ...
# 2019-04-15                     0.007525                0.009729  0.005496
# 2019-04-16                     0.007532                0.009731  0.005760
# 2019-04-17                     0.007574                0.009485  0.006229
# 2019-04-18                     0.007328                0.009475  0.005834
# 2019-04-22                     0.006197                0.009104  0.005831
#
#               Algo 2  S&P 500 Returns
# Date
# 2015-03-03       NaN              NaN
# 2015-03-04       NaN              NaN
# 2015-03-05       NaN              NaN
# 2015-03-06       NaN              NaN
# 2015-03-09       NaN              NaN
# ...              ...              ...
# 2019-04-15  0.007572         0.006532
# 2019-04-16  0.007053         0.006571
# 2019-04-17  0.007165         0.006505
# 2019-04-18  0.007172         0.006137
# 2019-04-22  0.007113         0.004302
#
# [1042 rows x 7 columns]

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
price_corr = column_appended_data.corr()

# Display de correlation matrix
price_corr.style.background_gradient(cmap="summer")
# Out:
# <style type="text/css">
# #T_16f89_row0_col0, #T_16f89_row1_col1, #T_16f89_row2_col2, #T_16f89_row3_col3, #T_16f89_row4_col4, #T_16f89_row5_col5, #T_16f89_row6_col6 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_16f89_row0_col1 {
#   background-color: #b2d866;
#   color: #000000;
# }
# #T_16f89_row0_col2, #T_16f89_row2_col0 {
#   background-color: #8fc766;
#   color: #000000;
# }
# #T_16f89_row0_col3, #T_16f89_row3_col0 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_16f89_row0_col4 {
#   background-color: #57ab66;
#   color: #f1f1f1;
# }
# #T_16f89_row0_col5, #T_16f89_row5_col0 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_16f89_row0_col6, #T_16f89_row2_col6 {
#   background-color: #088466;
#   color: #f1f1f1;
# }
# #T_16f89_row1_col0 {
#   background-color: #b3d966;
#   color: #000000;
# }
# #T_16f89_row1_col2 {
#   background-color: #6fb766;
#   color: #f1f1f1;
# }
# #T_16f89_row1_col3 {
#   background-color: #8dc666;
#   color: #000000;
# }
# #T_16f89_row1_col4, #T_16f89_row4_col5 {
#   background-color: #4aa466;
#   color: #f1f1f1;
# }
# #T_16f89_row1_col5 {
#   background-color: #add666;
#   color: #000000;
# }
# #T_16f89_row1_col6 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_16f89_row2_col1 {
#   background-color: #6db666;
#   color: #f1f1f1;
# }
# #T_16f89_row2_col3 {
#   background-color: #6eb666;
#   color: #f1f1f1;
# }
# #T_16f89_row2_col4 {
#   background-color: #319866;
#   color: #f1f1f1;
# }
# #T_16f89_row2_col5, #T_16f89_row5_col2 {
#   background-color: #82c066;
#   color: #000000;
# }
# #T_16f89_row3_col1 {
#   background-color: #8ac466;
#   color: #000000;
# }
# #T_16f89_row3_col2 {
#   background-color: #6cb666;
#   color: #f1f1f1;
# }
# #T_16f89_row3_col4 {
#   background-color: #50a866;
#   color: #f1f1f1;
# }
# #T_16f89_row3_col5 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_16f89_row3_col6 {
#   background-color: #048266;
#   color: #f1f1f1;
# }
# #T_16f89_row4_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_16f89_row4_col1 {
#   background-color: #42a066;
#   color: #f1f1f1;
# }
# #T_16f89_row4_col2 {
#   background-color: #2a9466;
#   color: #f1f1f1;
# }
# #T_16f89_row4_col3 {
#   background-color: #4da666;
#   color: #f1f1f1;
# }
# #T_16f89_row4_col6, #T_16f89_row6_col0, #T_16f89_row6_col1, #T_16f89_row6_col2, #T_16f89_row6_col3, #T_16f89_row6_col4, #T_16f89_row6_col5 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_16f89_row5_col1 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_16f89_row5_col3 {
#   background-color: #b1d866;
#   color: #000000;
# }
# #T_16f89_row5_col4 {
#   background-color: #4fa766;
#   color: #f1f1f1;
# }
# #T_16f89_row5_col6 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_16f89_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>
#       <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>
#       <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>
#       <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>
#       <th class="col_heading level0 col4" >Algo 1</th>
#       <th class="col_heading level0 col5" >Algo 2</th>
#       <th class="col_heading level0 col6" >S&P 500 Returns</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16f89_level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#       <td id="T_16f89_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_16f89_row0_col1" class="data row0 col1" >0.699823</td>
#       <td id="T_16f89_row0_col2" class="data row0 col2" >0.561040</td>
#       <td id="T_16f89_row0_col3" class="data row0 col3" >0.754157</td>
#       <td id="T_16f89_row0_col4" class="data row0 col4" >0.320901</td>
#       <td id="T_16f89_row0_col5" class="data row0 col5" >0.826730</td>
#       <td id="T_16f89_row0_col6" class="data row0 col6" >0.000574</td>
#     </tr>
#     <tr>
#       <th id="T_16f89_level0_row1" class="row_heading level0 row1" >PAULSON & CO.INC. </th>
#       <td id="T_16f89_row1_col0" class="data row1 col0" >0.699823</td>
#       <td id="T_16f89_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_16f89_row1_col2" class="data row1 col2" >0.434308</td>
#       <td id="T_16f89_row1_col3" class="data row1 col3" >0.545451</td>
#       <td id="T_16f89_row1_col4" class="data row1 col4" >0.268631</td>
#       <td id="T_16f89_row1_col5" class="data row1 col5" >0.678085</td>
#       <td id="T_16f89_row1_col6" class="data row1 col6" >0.013549</td>
#     </tr>
#     <tr>
#       <th id="T_16f89_level0_row2" class="row_heading level0 row2" >TIGER GLOBAL MANAGEMENT LLC</th>
#       <td id="T_16f89_row2_col0" class="data row2 col0" >0.561040</td>
#       <td id="T_16f89_row2_col1" class="data row2 col1" >0.434308</td>
#       <td id="T_16f89_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_16f89_row2_col3" class="data row2 col3" >0.424125</td>
#       <td id="T_16f89_row2_col4" class="data row2 col4" >0.164114</td>
#       <td id="T_16f89_row2_col5" class="data row2 col5" >0.507160</td>
#       <td id="T_16f89_row2_col6" class="data row2 col6" >-0.001505</td>
#     </tr>
#     <tr>
#       <th id="T_16f89_level0_row3" class="row_heading level0 row3" >BERKSHIRE HATHAWAY INC</th>
#       <td id="T_16f89_row3_col0" class="data row3 col0" >0.754157</td>
#       <td id="T_16f89_row3_col1" class="data row3 col1" >0.545451</td>
#       <td id="T_16f89_row3_col2" class="data row3 col2" >0.424125</td>
#       <td id="T_16f89_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_16f89_row3_col4" class="data row3 col4" >0.291678</td>
#       <td id="T_16f89_row3_col5" class="data row3 col5" >0.687756</td>
#       <td id="T_16f89_row3_col6" class="data row3 col6" >-0.013856</td>
#     </tr>
#     <tr>
#       <th id="T_16f89_level0_row4" class="row_heading level0 row4" >Algo 1</th>
#       <td id="T_16f89_row4_col0" class="data row4 col0" >0.320901</td>
#       <td id="T_16f89_row4_col1" class="data row4 col1" >0.268631</td>
#       <td id="T_16f89_row4_col2" class="data row4 col2" >0.164114</td>
#       <td id="T_16f89_row4_col3" class="data row4 col3" >0.291678</td>
#       <td id="T_16f89_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_16f89_row4_col5" class="data row4 col5" >0.287852</td>
#       <td id="T_16f89_row4_col6" class="data row4 col6" >-0.033963</td>
#     </tr>
#     <tr>
#       <th id="T_16f89_level0_row5" class="row_heading level0 row5" >Algo 2</th>
#       <td id="T_16f89_row5_col0" class="data row5 col0" >0.826730</td>
#       <td id="T_16f89_row5_col1" class="data row5 col1" >0.678085</td>
#       <td id="T_16f89_row5_col2" class="data row5 col2" >0.507160</td>
#       <td id="T_16f89_row5_col3" class="data row5 col3" >0.687756</td>
#       <td id="T_16f89_row5_col4" class="data row5 col4" >0.287852</td>
#       <td id="T_16f89_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_16f89_row5_col6" class="data row5 col6" >-0.002192</td>
#     </tr>
#     <tr>
#       <th id="T_16f89_level0_row6" class="row_heading level0 row6" >S&P 500 Returns</th>
#       <td id="T_16f89_row6_col0" class="data row6 col0" >0.000574</td>
#       <td id="T_16f89_row6_col1" class="data row6 col1" >0.013549</td>
#       <td id="T_16f89_row6_col2" class="data row6 col2" >-0.001505</td>
#       <td id="T_16f89_row6_col3" class="data row6 col3" >-0.013856</td>
#       <td id="T_16f89_row6_col4" class="data row6 col4" >-0.033963</td>
#       <td id="T_16f89_row6_col5" class="data row6 col5" >-0.002192</td>
#       <td id="T_16f89_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = column_appended_data['BERKSHIRE HATHAWAY INC'].rolling(60).cov(sp500_daily_returns)
# Calculate variance of S&P 500
variance = sp500_daily_returns.rolling(60).var()
# Computing beta
beta = covariance / variance
# Plot beta trend
beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
column_appended_data.ewm(21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe=(column_appended_data.mean()*252) / (all_portfolio_std * np.sqrt(252)) 
sharpe
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                        NaN                 NaN
# 2015-03-05                        NaN                 NaN
# 2015-03-06                        NaN                 NaN
# 2015-03-09                        NaN                 NaN
# ...                               ...                 ...
# 2019-04-15                   0.397950           -0.554659
# 2019-04-16                   0.403469           -0.554694
# 2019-04-17                   0.399764           -0.541963
# 2019-04-18                   0.408222           -0.547794
# 2019-04-22                   0.457713           -0.539451
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                          NaN                     NaN       NaN
# 2015-03-05                          NaN                     NaN       NaN
# 2015-03-06                          NaN                     NaN       NaN
# 2015-03-09                          NaN                     NaN       NaN
# ...                                 ...                     ...       ...
# 2019-04-15                    -0.188534                0.805632  1.899639
# 2019-04-16                    -0.188351                0.805525  1.812639
# 2019-04-17                    -0.187303                0.826354  1.676102
# 2019-04-18                    -0.193592                0.827293  1.789645
# 2019-04-22                    -0.228937                0.860971  1.790562
#
#               Algo 2  S&P 500 Returns
# Date
# 2015-03-03       NaN              NaN
# 2015-03-04       NaN              NaN
# 2015-03-05       NaN              NaN
# 2015-03-06       NaN              NaN
# 2015-03-09       NaN              NaN
# ...              ...              ...
# 2019-04-15  0.533522        -0.681685
# 2019-04-16  0.572812        -0.677667
# 2019-04-17  0.563866        -0.684533
# 2019-04-18  0.563319        -0.725568
# 2019-04-22  0.567981        -1.035134
#
# [1042 rows x 7 columns]

# %%
# Visualize the sharpe ratios as a bar plot
sharpe.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algorithmic strategies 1 out performed all the whales and S&P 500 portfolios, and algo 2 outperformed 3 of the 4 whale portfolios as well as S&P 500 portfolio.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
csv_path = Path('Resources/aapl_historical.csv')

# %%
aapl_df = pd.read_csv(csv_path, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True )
aapl_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
csv_path = Path('Resources/cost_historical.csv')

# %%
# Reading data from 2nd stock
cost_df = pd.read_csv(csv_path, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
cost_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
csv_path = Path('Resources/goog_historical.csv')

# %%
# Reading data from 3rd stock
goog_df = pd.read_csv(csv_path, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True) 
goog_df.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Combine all stocks in a single DataFrame
custom_combined_df = pd.concat([aapl_df, cost_df, goog_df], axis="rows", join="inner")
custom_combined_df
custom_combined_df.sort_index(inplace=True)
custom_combined_df.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-11   AAPL   188.59
# 2018-05-11   COST   195.76
# 2018-05-14   AAPL   188.15
# 2018-05-14   COST   195.88

# %%
# Reorganize portfolio data by having a column per symbol
cp = custom_combined_df.pivot_table(values="NOCP", index="Trade DATE", columns="Symbol")
cp.head()
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate daily returns
cp.plot()

# Drop NAs
cp.dropna(inplace=True)

# Display sample data
cp.head()
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_returns = cp.dot(weights)

# Display sample data
portfolio_returns.head()
# Out:
# Trade DATE
# 2018-05-11    494.203333
# 2018-05-14    494.743333
# 2018-05-15    487.050000
# 2018-05-16    489.553333
# 2018-05-17    488.393333
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_returns = pd.concat([column_appended_data, cp], axis="columns", join="inner")
combined_returns
combined_returns.sort_index(inplace=True)
combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2  S&P 500 Returns    AAPL    COST     GOOG
# 2018-05-11  0.000281        -0.000883  188.59  195.76  1098.26
# 2018-05-14  0.001635         0.006889  188.15  195.88  1100.20
# 2018-05-15 -0.001139        -0.004044  186.44  195.48  1079.23
# 2018-05-16  0.003341         0.000857  188.18  198.71  1081.77
# 2018-05-17  0.005205         0.002639  186.99  199.60  1078.59

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_returns.dropna(inplace=True)
combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# ...                                 ...                     ...       ...
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2  S&P 500 Returns    AAPL    COST     GOOG
# 2018-05-11  0.000281        -0.000883  188.59  195.76  1098.26
# 2018-05-14  0.001635         0.006889  188.15  195.88  1100.20
# 2018-05-15 -0.001139        -0.004044  186.44  195.48  1079.23
# 2018-05-16  0.003341         0.000857  188.18  198.71  1081.77
# 2018-05-17  0.005205         0.002639  186.99  199.60  1078.59
# ...              ...              ...     ...     ...      ...
# 2019-04-15 -0.004572        -0.000509  199.23  246.33  1221.10
# 2019-04-16  0.002899         0.002279  199.25  245.34  1227.13
# 2019-04-17 -0.005228        -0.001577  203.13  245.56  1236.34
# 2019-04-18 -0.001229        -0.001011  203.86  245.81  1236.37
# 2019-04-22 -0.001936        -0.008764  204.53  243.42  1248.84
#
# [237 rows x 10 columns]

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_returns * np.sqrt(252)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.074875            0.015590
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.011523           -0.022364
# 2018-05-16                   0.137112            0.099126
# 2018-05-17                  -0.031042            0.040065
# ...                               ...                 ...
# 2019-04-15                  -0.022573           -0.018356
# 2019-04-16                   0.042852            0.006162
# 2019-04-17                  -0.045984           -0.102663
# 2019-04-18                   0.022985            0.019396
# 2019-04-22                  -0.041047           -0.116402
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.041663               -0.065476  0.005676
# 2018-05-14                     0.000000                0.000000  0.014523
# 2018-05-15                    -0.050632               -0.231862 -0.018014
# 2018-05-16                     0.086985                0.068418 -0.036931
# 2018-05-17                    -0.099488               -0.081591 -0.110316
# ...                                 ...                     ...       ...
# 2019-04-15                     0.006317               -0.166561 -0.068757
# 2019-04-16                    -0.013191                0.013282 -0.110244
# 2019-04-17                    -0.069998                0.051150 -0.163524
# 2019-04-18                     0.009232                0.030417 -0.009333
# 2019-04-22                    -0.057787               -0.017268  0.010740
#
#               Algo 2  S&P 500 Returns         AAPL         COST          GOOG
# 2018-05-11  0.004466        -0.014013  2993.773439  3107.593660  17434.337009
# 2018-05-14  0.025952         0.109364  2986.788655  3109.498601  17465.133555
# 2018-05-15 -0.018078        -0.064199  2959.643247  3103.148798  17132.245125
# 2018-05-16  0.053034         0.013598  2987.264890  3154.423458  17172.566375
# 2018-05-17  0.082625         0.041896  2968.374226  3168.551770  17122.085440
# ...              ...              ...          ...          ...           ...
# 2019-04-15 -0.072573        -0.008082  3162.678202  3910.367523  19384.361556
# 2019-04-16  0.046027         0.036177  3162.995692  3894.651760  19480.084838
# 2019-04-17 -0.082994        -0.025027  3224.588783  3898.144152  19626.289056
# 2019-04-18 -0.019513        -0.016049  3236.177174  3902.112779  19626.765291
# 2019-04-22 -0.030728        -0.139120  3246.813094  3864.172705  19824.720404
#
# [237 rows x 10 columns]

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
combined_returns.rolling(window=21).std()
# Plot rolling standard deviation
combined_returns
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# ...                                 ...                     ...       ...
# 2019-04-15                     0.000398               -0.010492 -0.004331
# 2019-04-16                    -0.000831                0.000837 -0.006945
# 2019-04-17                    -0.004409                0.003222 -0.010301
# 2019-04-18                     0.000582                0.001916 -0.000588
# 2019-04-22                    -0.003640               -0.001088  0.000677
#
#               Algo 2  S&P 500 Returns    AAPL    COST     GOOG
# 2018-05-11  0.000281        -0.000883  188.59  195.76  1098.26
# 2018-05-14  0.001635         0.006889  188.15  195.88  1100.20
# 2018-05-15 -0.001139        -0.004044  186.44  195.48  1079.23
# 2018-05-16  0.003341         0.000857  188.18  198.71  1081.77
# 2018-05-17  0.005205         0.002639  186.99  199.60  1078.59
# ...              ...              ...     ...     ...      ...
# 2019-04-15 -0.004572        -0.000509  199.23  246.33  1221.10
# 2019-04-16  0.002899         0.002279  199.25  245.34  1227.13
# 2019-04-17 -0.005228        -0.001577  203.13  245.56  1236.34
# 2019-04-18 -0.001229        -0.001011  203.86  245.81  1236.37
# 2019-04-22 -0.001936        -0.008764  204.53  243.42  1248.84
#
# [237 rows x 10 columns]

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
custom_corr = combined_returns.corr()
custom_corr.style.background_gradient(cmap="summer")
# Out:
# <style type="text/css">
# #T_411c2_row0_col0, #T_411c2_row1_col1, #T_411c2_row2_col2, #T_411c2_row3_col3, #T_411c2_row4_col4, #T_411c2_row5_col5, #T_411c2_row6_col6, #T_411c2_row7_col7, #T_411c2_row8_col8, #T_411c2_row9_col9 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_411c2_row0_col1, #T_411c2_row1_col0 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_411c2_row0_col2 {
#   background-color: #79bc66;
#   color: #000000;
# }
# #T_411c2_row0_col3 {
#   background-color: #d4ea66;
#   color: #000000;
# }
# #T_411c2_row0_col4 {
#   background-color: #62b066;
#   color: #f1f1f1;
# }
# #T_411c2_row0_col5 {
#   background-color: #dfef66;
#   color: #000000;
# }
# #T_411c2_row0_col6 {
#   background-color: #078366;
#   color: #f1f1f1;
# }
# #T_411c2_row0_col7, #T_411c2_row0_col8, #T_411c2_row4_col8, #T_411c2_row6_col5 {
#   background-color: #088466;
#   color: #f1f1f1;
# }
# #T_411c2_row0_col9 {
#   background-color: #2d9666;
#   color: #f1f1f1;
# }
# #T_411c2_row1_col2 {
#   background-color: #7bbd66;
#   color: #000000;
# }
# #T_411c2_row1_col3 {
#   background-color: #add666;
#   color: #000000;
# }
# #T_411c2_row1_col4, #T_411c2_row5_col2 {
#   background-color: #67b366;
#   color: #f1f1f1;
# }
# #T_411c2_row1_col5, #T_411c2_row3_col5, #T_411c2_row5_col3 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_411c2_row1_col6, #T_411c2_row3_col7, #T_411c2_row3_col8, #T_411c2_row4_col9, #T_411c2_row5_col8, #T_411c2_row6_col1, #T_411c2_row6_col2, #T_411c2_row7_col0, #T_411c2_row7_col3, #T_411c2_row7_col5, #T_411c2_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_411c2_row1_col7, #T_411c2_row6_col9 {
#   background-color: #158a66;
#   color: #f1f1f1;
# }
# #T_411c2_row1_col8, #T_411c2_row5_col7 {
#   background-color: #028066;
#   color: #f1f1f1;
# }
# #T_411c2_row1_col9, #T_411c2_row5_col9, #T_411c2_row9_col5 {
#   background-color: #329866;
#   color: #f1f1f1;
# }
# #T_411c2_row2_col0 {
#   background-color: #80c066;
#   color: #000000;
# }
# #T_411c2_row2_col1 {
#   background-color: #83c166;
#   color: #000000;
# }
# #T_411c2_row2_col3 {
#   background-color: #60b066;
#   color: #f1f1f1;
# }
# #T_411c2_row2_col4 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_411c2_row2_col5 {
#   background-color: #73b966;
#   color: #f1f1f1;
# }
# #T_411c2_row2_col6, #T_411c2_row6_col8, #T_411c2_row7_col1, #T_411c2_row7_col4, #T_411c2_row8_col1 {
#   background-color: #0f8766;
#   color: #f1f1f1;
# }
# #T_411c2_row2_col7 {
#   background-color: #1a8c66;
#   color: #f1f1f1;
# }
# #T_411c2_row2_col8 {
#   background-color: #098466;
#   color: #f1f1f1;
# }
# #T_411c2_row2_col9, #T_411c2_row9_col0 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_411c2_row3_col0 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_411c2_row3_col1 {
#   background-color: #abd566;
#   color: #000000;
# }
# #T_411c2_row3_col2 {
#   background-color: #51a866;
#   color: #f1f1f1;
# }
# #T_411c2_row3_col4 {
#   background-color: #5faf66;
#   color: #f1f1f1;
# }
# #T_411c2_row3_col6, #T_411c2_row6_col0, #T_411c2_row7_col2 {
#   background-color: #058266;
#   color: #f1f1f1;
# }
# #T_411c2_row3_col9 {
#   background-color: #209066;
#   color: #f1f1f1;
# }
# #T_411c2_row4_col0 {
#   background-color: #5eae66;
#   color: #f1f1f1;
# }
# #T_411c2_row4_col1 {
#   background-color: #65b266;
#   color: #f1f1f1;
# }
# #T_411c2_row4_col2, #T_411c2_row8_col6 {
#   background-color: #1b8d66;
#   color: #f1f1f1;
# }
# #T_411c2_row4_col3 {
#   background-color: #61b066;
#   color: #f1f1f1;
# }
# #T_411c2_row4_col5 {
#   background-color: #69b466;
#   color: #f1f1f1;
# }
# #T_411c2_row4_col6 {
#   background-color: #018066;
#   color: #f1f1f1;
# }
# #T_411c2_row4_col7, #T_411c2_row9_col6 {
#   background-color: #128866;
#   color: #f1f1f1;
# }
# #T_411c2_row5_col0 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_411c2_row5_col1 {
#   background-color: #cbe566;
#   color: #000000;
# }
# #T_411c2_row5_col4 {
#   background-color: #68b366;
#   color: #f1f1f1;
# }
# #T_411c2_row5_col6, #T_411c2_row6_col4 {
#   background-color: #048266;
#   color: #f1f1f1;
# }
# #T_411c2_row6_col3 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_411c2_row6_col7 {
#   background-color: #309866;
#   color: #f1f1f1;
# }
# #T_411c2_row7_col6 {
#   background-color: #2b9566;
#   color: #f1f1f1;
# }
# #T_411c2_row7_col8 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_411c2_row7_col9 {
#   background-color: #91c866;
#   color: #000000;
# }
# #T_411c2_row8_col0, #T_411c2_row8_col3 {
#   background-color: #138966;
#   color: #f1f1f1;
# }
# #T_411c2_row8_col2 {
#   background-color: #068266;
#   color: #f1f1f1;
# }
# #T_411c2_row8_col4 {
#   background-color: #188c66;
#   color: #f1f1f1;
# }
# #T_411c2_row8_col5 {
#   background-color: #118866;
#   color: #f1f1f1;
# }
# #T_411c2_row8_col7 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_411c2_row8_col9 {
#   background-color: #84c266;
#   color: #000000;
# }
# #T_411c2_row9_col1 {
#   background-color: #2f9766;
#   color: #f1f1f1;
# }
# #T_411c2_row9_col2 {
#   background-color: #168a66;
#   color: #f1f1f1;
# }
# #T_411c2_row9_col3 {
#   background-color: #229066;
#   color: #f1f1f1;
# }
# #T_411c2_row9_col7 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_411c2_row9_col8 {
#   background-color: #7cbe66;
#   color: #000000;
# }
# </style>
# <table id="T_411c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >SOROS FUND MANAGEMENT LLC</th>
#       <th class="col_heading level0 col1" >PAULSON & CO.INC. </th>
#       <th class="col_heading level0 col2" >TIGER GLOBAL MANAGEMENT LLC</th>
#       <th class="col_heading level0 col3" >BERKSHIRE HATHAWAY INC</th>
#       <th class="col_heading level0 col4" >Algo 1</th>
#       <th class="col_heading level0 col5" >Algo 2</th>
#       <th class="col_heading level0 col6" >S&P 500 Returns</th>
#       <th class="col_heading level0 col7" >AAPL</th>
#       <th class="col_heading level0 col8" >COST</th>
#       <th class="col_heading level0 col9" >GOOG</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_411c2_level0_row0" class="row_heading level0 row0" >SOROS FUND MANAGEMENT LLC</th>
#       <td id="T_411c2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_411c2_row0_col1" class="data row0 col1" >0.791031</td>
#       <td id="T_411c2_row0_col2" class="data row0 col2" >0.476938</td>
#       <td id="T_411c2_row0_col3" class="data row0 col3" >0.816190</td>
#       <td id="T_411c2_row0_col4" class="data row0 col4" >0.336890</td>
#       <td id="T_411c2_row0_col5" class="data row0 col5" >0.861989</td>
#       <td id="T_411c2_row0_col6" class="data row0 col6" >-0.028091</td>
#       <td id="T_411c2_row0_col7" class="data row0 col7" >-0.050062</td>
#       <td id="T_411c2_row0_col8" class="data row0 col8" >0.029908</td>
#       <td id="T_411c2_row0_col9" class="data row0 col9" >0.116906</td>
#     </tr>
#     <tr>
#       <th id="T_411c2_level0_row1" class="row_heading level0 row1" >PAULSON & CO.INC. </th>
#       <td id="T_411c2_row1_col0" class="data row1 col0" >0.791031</td>
#       <td id="T_411c2_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_411c2_row1_col2" class="data row1 col2" >0.484917</td>
#       <td id="T_411c2_row1_col3" class="data row1 col3" >0.650132</td>
#       <td id="T_411c2_row1_col4" class="data row1 col4" >0.360668</td>
#       <td id="T_411c2_row1_col5" class="data row1 col5" >0.783856</td>
#       <td id="T_411c2_row1_col6" class="data row1 col6" >-0.059893</td>
#       <td id="T_411c2_row1_col7" class="data row1 col7" >0.005247</td>
#       <td id="T_411c2_row1_col8" class="data row1 col8" >0.006184</td>
#       <td id="T_411c2_row1_col9" class="data row1 col9" >0.136350</td>
#     </tr>
#     <tr>
#       <th id="T_411c2_level0_row2" class="row_heading level0 row2" >TIGER GLOBAL MANAGEMENT LLC</th>
#       <td id="T_411c2_row2_col0" class="data row2 col0" >0.476938</td>
#       <td id="T_411c2_row2_col1" class="data row2 col1" >0.484917</td>
#       <td id="T_411c2_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_411c2_row2_col3" class="data row2 col3" >0.323931</td>
#       <td id="T_411c2_row2_col4" class="data row2 col4" >0.113568</td>
#       <td id="T_411c2_row2_col5" class="data row2 col5" >0.408381</td>
#       <td id="T_411c2_row2_col6" class="data row2 col6" >0.005812</td>
#       <td id="T_411c2

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
covariance = cp['AAPL'].rolling(60).cov(sp500_daily_returns)
variance = sp500_daily_returns.rolling(60).var()
beta = covariance / variance
beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
covariance = cp['COST'].rolling(60).cov(sp500_daily_returns)
variance = sp500_daily_returns.rolling(60).var()
beta = covariance / variance
beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
covariance = cp['GOOG'].rolling(60).cov(sp500_daily_returns)
variance = sp500_daily_returns.rolling(60).var()
beta = covariance / variance
beta.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe=(combined_returns.mean()*252) / (column_appended_data * np.sqrt(252)) 
sharpe
# Out:
#             AAPL     Algo 1    Algo 2  BERKSHIRE HATHAWAY INC  COST  GOOG  \
# Date
# 2015-03-03   NaN  -8.669149 -0.087434               -0.201207   NaN   NaN
# 2015-03-04   NaN  -1.960293  0.034358                0.313709   NaN   NaN
# 2015-03-05   NaN -17.629026  0.019203                0.196491   NaN   NaN
# 2015-03-06   NaN  -3.396701 -0.007244               -0.100905   NaN   NaN
# 2015-03-09   NaN  -3.090952  0.063701               -0.799818   NaN   NaN
# ...          ...        ...       ...                     ...   ...   ...
# 2019-04-15   NaN  -3.887226 -0.018159               -0.125965   NaN   NaN
# 2019-04-16   NaN  -2.424378  0.028632                1.579616   NaN   NaN
# 2019-04-17   NaN  -1.634456 -0.015879                0.410180   NaN   NaN
# 2019-04-18   NaN -28.637700 -0.067538                0.689778   NaN   NaN
# 2019-04-22   NaN  24.885461 -0.042887               -1.215021   NaN   NaN
#
#             PAULSON & CO.INC.   S&P 500 Returns  SOROS FUND MANAGEMENT LLC  \
# Date
# 2015-03-03           -0.348354        -0.941380                  -2.515706
# 2015-03-04            0.535278         3.473380                   1.427699
# 2015-03-05            0.425653        -0.288604                   0.792740
# 2015-03-06           -0.485442         1.056122                  -0.402720
# 2015-03-09            0.410607        -0.240492                   5.467553
# ...                        ...              ...                        ...
# 2019-04-15           -1.500472         8.150496                  -2.238889
# 2019-04-16            4.469773        -1.820772                   1.179393
# 2019-04-17           -0.268276         2.631945                  -1.099044
# 2019-04-18            1.420010         4.104255                   2.198779
# 2019-04-22           -0.236611         0.473481                  -1.231239
#
#             TIGER GLOBAL MANAGEMENT LLC
# Date
# 2015-03-03                    31.091759
# 2015-03-04                     6.080155
# 2015-03-05                    -6.543192
# 2015-03-06                     1.816608
# 2015-03-09                    -2.636945
# ...                                 ...
# 2019-04-15                   -38.720241
# 2019-04-16                    18.541316
# 2019-04-17                     3.494052
# 2019-04-18                   -26.493008
# 2019-04-22                     4.232434
#
# [1042 rows x 10 columns]

# %%
# Visualize the sharpe ratios as a bar plot
sharpe.plot.bar()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
In full transparency, I can barely see how my portfolio did due to how the graph looks...but I am optimistic that my portfolio did great!
# Out:
#   File "C:\Users\sagui\AppData\Local\Temp\ipykernel_15692\2350882830.py", line 1
#     In full transparency, I can barely see how my portfolio did due to how the graph looks...but I am optimistic that my portfolio did great!
#           ^
# SyntaxError: invalid syntax
